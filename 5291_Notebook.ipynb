# %%
import pandas as pd
import numpy as np

# !mkdir data

from google.colab import drive
drive.mount('/content/drive')
# Out:
# mkdir: cannot create directory ‘data’: File exists
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
import zipfile
zip = zipfile.ZipFile('drive/MyDrive/5291Project/archive.zip')
zip.extractall()
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-1-5dff3ae02085> in <module>()
#       1 import zipfile
# ----> 2 zip = zipfile.ZipFile('drive/MyDrive/5293Project/archive.zip')
#       3 zip.extractall()
#
# /usr/lib/python3.7/zipfile.py in __init__(self, file, mode, compression, allowZip64, compresslevel)
#    1238             while True:
#    1239                 try:
# -> 1240                     self.fp = io.open(file, filemode)
#    1241                 except OSError:
#    1242                     if filemode in modeDict:
#
# FileNotFoundError: [Errno 2] No such file or directory: 'drive/MyDrive/5293Project/archive.zip'

# %%
data_US = pd.read_csv("US_youtube_trending_data.csv")
data_US.head(5)
import json #import data using python json module
with open('US_category_id.json','r') as f:
    category_data_us= json.loads(f.read())
US_cat = pd.json_normalize(category_data_us,record_path='items')
US_cat['id']= US_cat['id'].astype(int)
data_US = data_US.merge(US_cat,how ='left',left_on= 'categoryId',\
                                 right_on='id').rename(columns= {'snippet.title':'category_name'})
data_US.head(10)
# Out:
#       video_id                                              title  \
# 0  3C66w5Z0ixs                 I ASKED HER TO BE MY GIRLFRIEND...
# 1  M9Pmf9AB4Mo  Apex Legends | Stories from the Outlands – “Th...
# 2  J78aPJ3VyNs  I left youtube for a month and THIS is what ha...
# 3  kXLn3HkpjaA  XXL 2020 Freshman Class Revealed - Official An...
# 4  VIUo6yapDbc  Ultimate DIY Home Movie Theater for The LaBran...
# 5  w-aidBdvZo8  I Haven't Been Honest About My Injury.. Here's...
# 6  uet14uf9NsE                           OUR FIRST FAMILY INTRO!!
# 7  ua4QMFQATco                                 CGP Grey was WRONG
# 8  SnsPZj91R7E  SURPRISING MY DAD WITH HIS DREAM TRUCK!! | Lou...
# 9  SsWHMAhshPQ  Ovi x Natanael Cano x Aleman x Big Soto - Veng...
#
#             publishedAt                 channelId    channelTitle  categoryId  \
# 0  2020-08-11T19:20:14Z  UCvtRTOMP2TqYqu51xNrqAzg        Brawadis          22
# 1  2020-08-11T17:00:10Z  UC0ZV6M2THA81QT9hrVWJG3A    Apex Legends          20
# 2  2020-08-11T16:34:06Z  UCYzPXprvl5Y-Sf0g4vX-m6g   jacksepticeye          24
# 3  2020-08-11T16:38:55Z  UCbg_UMjlHJg_19SZckaKajg             XXL          10
# 4  2020-08-11T15:10:05Z  UCDVPcEbVLQgLZX0Rt6jo34A        Mr. Kate          26
# 5  2020-08-11T20:00:04Z  UC5zJwsFtEs9WYe3A76p7xIA  Professor Live          24
# 6  2020-08-12T00:17:41Z  UCDSJCBYqL7VQrlXfhr1RtwA   Les Do Makeup          26
# 7  2020-08-11T17:15:11Z  UC2C_jShtL725hvbm1arSV9w        CGP Grey          27
# 8  2020-08-10T22:26:59Z  UCZDdF_p-L88NWVpzF0vjvMQ    Louie's Life          24
# 9  2020-08-11T23:00:10Z  UC648rgJOboZlgcDbW00vTSA  Rancho Humilde          10
#
#           trending_date                                               tags  \
# 0  2020-08-12T00:00:00Z  brawadis|prank|basketball|skits|ghost|funny vi...
# 1  2020-08-12T00:00:00Z  Apex Legends|Apex Legends characters|new Apex ...
# 2  2020-08-12T00:00:00Z  jacksepticeye|funny|funny meme|memes|jacksepti...
# 3  2020-08-12T00:00:00Z  xxl freshman|xxl freshmen|2020 xxl freshman|20...
# 4  2020-08-12T00:00:00Z  The LaBrant Family|DIY|Interior Design|Makeove...
# 5  2020-08-12T00:00:00Z  Professor injury|professor achilles|professor ...
# 6  2020-08-12T00:00:00Z                                             [None]
# 7  2020-08-12T00:00:00Z                   cgpgrey|education|hello internet
# 8  2020-08-12T00:00:00Z  surprising|dad|father|papa|with|dream|car|truc...
# 9  2020-08-12T00:00:00Z  Vengo De Nada|Aleman|Ovi|Big Soto|Trap|Ovi Nat...
#
#    view_count   likes  ...                                  thumbnail_link  \
# 0     1514614  156908  ...  https://i.ytimg.com/vi/3C66w5Z0ixs/default.jpg
# 1     2381688  146739  ...  https://i.ytimg.com/vi/M9Pmf9AB4Mo/default.jpg
# 2     2038853  353787  ...  https://i.ytimg.com/vi/J78aPJ3VyNs/default.jpg
# 3      496771   23251  ...  https://i.ytimg.com/vi/kXLn3HkpjaA/default.jpg
# 4     1123889   45802  ...  https://i.ytimg.com/vi/VIUo6yapDbc/default.jpg
# 5      949491   77487  ...  https://i.ytimg.com/vi/w-aidBdvZo8/default.jpg
# 6      470446   47990  ...  https://i.ytimg.com/vi/uet14uf9NsE/default.jpg
# 7     1050143   89190  ...  https://i.ytimg.com/vi/ua4QMFQATco/default.jpg
# 8     1402687   95694  ...  https://i.ytimg.com/vi/SnsPZj91R7E/default.jpg
# 9      741028  113983  ...  https://i.ytimg.com/vi/SsWHMAhshPQ/default.jpg
#
#    comments_disabled ratings_disabled  \
# 0              False            False
# 1              False            False
# 2              False            False
# 3              False            False
# 4              False            False
# 5              False            False
# 6              False            False
# 7              False            False
# 8              False            False
# 9              False            False
#
#                                          description                   kind  \
# 0  SUBSCRIBE to BRAWADIS ▶ http://bit.ly/Subscrib...  youtube#videoCategory
# 1  While running her own modding shop, Ramya Pare...  youtube#videoCategory
# 2  I left youtube for a month and this is what ha...  youtube#videoCategory
# 3  Subscribe to XXL → http://bit.ly/subscribe-xxl...  youtube#videoCategory
# 4  Transforming The LaBrant Family's empty white ...  youtube#videoCategory
# 5  Subscribe To My Channel - https://www.youtube....  youtube#videoCategory
# 6  Hi babygirls!  Thank you so much for watching ...  youtube#videoCategory
# 7  ‣ What Was TEKOI: https://www.youtube.com/watc...  youtube#videoCategory
# 8  Since I was little, i've had these goals for m...  youtube#videoCategory
# 9  Vengo De Nada - Ovi x Natanael Cano x Aleman x...  youtube#videoCategory
#
#                           etag  id   category_name  snippet.assignable  \
# 0  QMEBz6mxVdklVaq8JwesPEw_4nI  22  People & Blogs                True
# 1  I3IL9xGIM3MsULlqR4tvCsEKv98  20          Gaming                True
# 2  Qi1csjh-POReitZEbR7CUw7dmao  24   Entertainment                True
# 3  HCjFMARbBeWjpm6PDfReCOMOZGA  10           Music                True
# 4  gYzt8dB8mlod-84ipMtjynYe9xU  26   Howto & Style                True
# 5  Qi1csjh-POReitZEbR7CUw7dmao  24   Entertainment                True
# 6  gYzt8dB8mlod-84ipMtjynYe9xU  26   Howto & Style                True
# 7  hHUhloYhyMMqVkQ4LH9sr3aRQoU  27       Education                True
# 8  Qi1csjh-POReitZEbR7CUw7dmao  24   Entertainment                True
# 9  HCjFMARbBeWjpm6PDfReCOMOZGA  10           Music                True
#
#           snippet.channelId
# 0  UCBR8-60-B28hp2BmDPdntcQ
# 1  UCBR8-60-B28hp2BmDPdntcQ
# 2  UCBR8-60-B28hp2BmDPdntcQ
# 3  UCBR8-60-B28hp2BmDPdntcQ
# 4  UCBR8-60-B28hp2BmDPdntcQ
# 5  UCBR8-60-B28hp2BmDPdntcQ
# 6  UCBR8-60-B28hp2BmDPdntcQ
# 7  UCBR8-60-B28hp2BmDPdntcQ
# 8  UCBR8-60-B28hp2BmDPdntcQ
# 9  UCBR8-60-B28hp2BmDPdntcQ
#
# [10 rows x 22 columns]

# %%
data_US.head(5)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-5-250018f7d404> in <module>()
# ----> 1 data_US.head(5)
#
# NameError: name 'data_US' is not defined
